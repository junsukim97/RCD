# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = plt.imread('left_curve.jpg')

plt.imshow(img)

# %%
img = plt.imread('left_curve.jpg')

img = img[20:230,:,:]
plt.imshow(img)

# %%
img = cv2.resize(img,dsize=(40, 40), interpolation=cv2.INTER_CUBIC)
img.shape
plt.imshow(img)

# %%
orginal = plt.imread('xy_115_137_0_a73a784c-a43b-11eb-a7cd-4c1d96ff72a1.jpg')
change = orginal.copy()

#change[100:140, 100:140, :] = img

plt.imshow(change)
plt.show()

# %%
import glob
import os

dir = "xy_123_140_000_75c87c2e-208b-11ec-9ef6-4c1d96ff72a1.jpg"

x = int(dir.split("_")[1])
y = int(dir.split("_")[2])
z = int(dir.split("_")[3])

#h W C 
xoffset, yoffset = img.shape[1]//2, img.shape[0]//2
x_start = x - xoffset
x_end = x + xoffset
y_start = y - yoffset
y_end = y + yoffset

# %%
for r in range(40):
    for i, j in zip(img[:, :, :], change[y_start:y_end, x_start:x_end, :]):
        if (sum(i[r][1:3] == 255) != 2): # 기호가 존재하는 부분에서만
            j[r] = i[r] #해당 기호 값을 원본 이미지로 가져온다.

# %%
plt.imshow(change)

# %%
from uuid import uuid1

# 0 : left 1 : right
plt.imsave('xyz_%d_%d_%d_%d_%s.jpg' %(x, y, z, 0, uuid1()), change)

# %%
import glob

glob.glob()
